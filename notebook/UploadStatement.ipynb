# %% [markdown]
# # UploadStatement
# This function is responsible for processing a bank statement. Well worry about inputs and outputs later. The expected behavior is that given a document it is added to the the transaction table.

# %%
from main import get_database_connection, ping_db

conn = get_database_connection()
ping_db(conn)
# Out:
# Database connection is active.
# True
